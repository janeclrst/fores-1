# %% [markdown]
# # Start

# %%
import os
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
gan_images_path = os.listdir("datasets/gan/images")
gan_images_path = np.array([f"datasets/gan/images/{img}" for img in gan_images_path])

# %%
# Split the array into 6 portions
num_portions = 50
gan_images_path_portions = np.array_split(gan_images_path, num_portions)

# You can access each portion like this:
for i, portion in enumerate(gan_images_path_portions):
    print(f"Portion {i + 1} has {portion.shape[0]} elements.")
# Out:
# Portion 1 has 4482 elements.
# Portion 2 has 4482 elements.
# Portion 3 has 4482 elements.
# Portion 4 has 4482 elements.
# Portion 5 has 4482 elements.
# Portion 6 has 4482 elements.
# Portion 7 has 4482 elements.
# Portion 8 has 4482 elements.
# Portion 9 has 4482 elements.
# Portion 10 has 4482 elements.
# Portion 11 has 4482 elements.
# Portion 12 has 4482 elements.
# Portion 13 has 4482 elements.
# Portion 14 has 4481 elements.
# Portion 15 has 4481 elements.
# Portion 16 has 4481 elements.
# Portion 17 has 4481 elements.
# Portion 18 has 4481 elements.
# Portion 19 has 4481 elements.
# Portion 20 has 4481 elements.
# Portion 21 has 4481 elements.
# Portion 22 has 4481 elements.
# Portion 23 has 4481 elements.
# Portion 24 has 4481 elements.
# Portion 25 has 4481 elements.
# Portion 26 has 4481 elements.
# Portion 27 has 4481 elements.
# Portion 28 has 4481 elements.
# Portion 29 has 4481 elements.
# Portion 30 has 4481 elements.
# Portion 31 has 4481 elements.
# ...

# %%
def zoom_center(img, zoom_factor=2):
    x_width = img.shape[1]
    y_height = img.shape[0]

    x1 = int(0.5 * x_width * (1 - 1 / zoom_factor))
    y1 = int(0.5 * y_height * (1 - 1 / zoom_factor))

    x2 = int(x_width - 0.5 * x_width * (1 - 1 / zoom_factor))
    y2 = int(y_height - 0.5 * y_height * (1 - 1 / zoom_factor))
    
    # Crop then scale
    cropped_img = img[y1:y2, x1:x2]
    return cv2.resize(cropped_img, None, fx=zoom_factor, fy=zoom_factor)

def display_image(img, title=None):
    plt.figure(figsize=(3, 3))
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    if title:
        plt.title(title)
    plt.axis('off')
    plt.show()
    
def extract_hsv_mean(img):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h = np.mean(hsv[:, :, 0])
    s = np.mean(hsv[:, :, 1])
    v = np.mean(hsv[:, :, 2])
    return np.array([h, s, v])

def extract_hsv_mode(img):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h = stats.mode(hsv[:, :, 0].flatten())[0]
    s = stats.mode(hsv[:, :, 1].flatten())[0]
    v = stats.mode(hsv[:, :, 2].flatten())[0]
    return np.array([h, s, v])

# %% [markdown]
# ## Jalanin ini dulu satu per satu tiap portion nya

# %% [markdown]
# # Batas 1

# %%
gan_images_portion_one = np.array([cv2.cvtColor(cv2.imread(file_path), cv2.COLOR_BGR2RGB) for file_path in gan_images_path_portions[0]])

# %%
# gan_images_portion_eight = np.array([cv2.cvtColor(cv2.imread(file_path), cv2.COLOR_BGR2RGB) for file_path in gan_images_path_portions[7]])

# %%
# gan_images_portion_fourteen = np.array([cv2.cvtColor(cv2.imread(file_path), cv2.COLOR_BGR2RGB) for file_path in gan_images_path_portions[13]])

# %%
# gan_images_portion_sixteen = np.array([cv2.cvtColor(cv2.imread(file_path), cv2.COLOR_BGR2RGB) for file_path in gan_images_path_portions[15]])

# %%
# gan_images_portion_nineteen = np.array([cv2.cvtColor(cv2.imread(file_path), cv2.COLOR_BGR2RGB) for file_path in gan_images_path_portions[18]])

# %%
# gan_images_portion_forty_one = np.array([cv2.cvtColor(cv2.imread(file_path), cv2.COLOR_BGR2RGB) for file_path in gan_images_path_portions[40]])

# %%
# gan_images_portion_forty_nine = np.array([cv2.cvtColor(cv2.imread(file_path), cv2.COLOR_BGR2RGB) for file_path in gan_images_path_portions[48]])

# %% [markdown]
# ## Batas 2

# %% [markdown]
# # Continue

# %%
gan_zoomed_images = np.array([zoom_center(img, 7) for img in gan_images_portion_one])
#                                                      TODO: ^~~~~~ ganti variable sesuai portion

# %%
plt.figure(figsize=(10, 10))
for i in range(5):
    plt.subplot(1, 5, i+1)
    plt.imshow(gan_zoomed_images[i])
    # plt.title(gan_images_portion_one.iloc[i]['file'].split('/')[0])
    plt.axis('off')
plt.show()

# %%
df = pd.read_csv('datasets/gan/data/portions/1.csv')

# %%
df
# Out:
#                                                    file  hsv_mean_h  \
# 0     datasets/gan/images/XUMjlGLbfjZ8HmkQ2EvXL2dacv...  111.960962
# 1     datasets/gan/images/4WPKvjIxnpPNqSqVABTZubeIF9...  115.044329
# 2     datasets/gan/images/7GuBG5XwibAmVoATRGTSAYrhzl...  110.441851
# 3     datasets/gan/images/HqQ04u6KqZeINKzNGkzBaaCw2Z...  110.111626
# 4     datasets/gan/images/EwKC3j8EEkQtvWwk2E6kdpAyzY...  110.697349
# ...                                                 ...         ...
# 4477  datasets/gan/images/H0GjPjMsKYUEtfU0XM1OOGP7dH...  116.196604
# 4478  datasets/gan/images/JYyqVflxCEr0mcoXn72cfYNK8P...  112.170313
# 4479  datasets/gan/images/lCzGUxuBaha543akCfjttyMbRv...  111.601007
# 4480  datasets/gan/images/r2FqWTIUkRgs9WcYvG6jI8vIRM...  114.413068
# 4481  datasets/gan/images/QiXY7MDu6XfxSxUP3LZ9S2KJ5B...  108.931421
#
#       hsv_mean_s  hsv_mean_v
# 0      93.646384  200.589398
# 1      82.940511  170.309099
# 2     103.284585  176.739625
# 3      85.754893  192.596356
# ...

# %%
plt.figure(figsize=(20, 20))
for i in range(13):
    plt.subplot(1, 13, i+1)
    # plt.imshow(cv2.cvtColor(gan_images_portion_one[i+5], cv2.COLOR_BGR2RGB))
    plt.imshow(gan_images_portion_one[i+0])
    plt.title(f"[{int(hsv_mean_h[i+0])} {int(hsv_mean_s[i+0])} {int(hsv_mean_v[i+0])}]")
    plt.axis('off')
plt.show()

# %%
gan_hsv_mean = np.array([extract_hsv_mean(img) for img in gan_zoomed_images])
gan_hsv_mode = np.array([extract_hsv_mode(img) for img in gan_zoomed_images])
# ini tinggal run aja

# %%
# extract every single channel from the HSV mean
hsv_mean_h = gan_hsv_mean[:, 0]
hsv_mean_s = gan_hsv_mean[:, 1]
hsv_mean_v = gan_hsv_mean[:, 2]

hsv_mode_h = gan_hsv_mode[:, 0]
hsv_mode_s = gan_hsv_mode[:, 1]
hsv_mode_v = gan_hsv_mode[:, 2]

# ini tinggal run aja

# %%
print(f"hsv_mean_h: {hsv_mean_h}")
print(f"hsv_mean_s: {hsv_mean_s}")
print(f"hsv_mean_v: {hsv_mean_v}")

print(f"hsv_mode_h: {hsv_mode_h}")
print(f"hsv_mode_s: {hsv_mode_s}")
print(f"hsv_mode_v: {hsv_mode_v}")
# Out:
# hsv_mean_h: [111.51613415 114.54745236 109.92448158 ... 111.35284051 114.13977453
#  108.54609238]
# hsv_mean_s: [ 94.6293825   83.23320404 102.43139338 ... 100.71211542  77.24029292
#  116.60200162]
# hsv_mean_v: [206.48269381 170.33977434 186.7705869  ... 180.92126958 182.972978
#  216.65349566]
# hsv_mode_h: [111 114 110 ... 112 114 108]
# hsv_mode_s: [ 82  86  95 ... 103  85 112]
# hsv_mode_v: [226 218 212 ... 225 186 221]

# %%
# Print the min and max of each channel of the HSV mean
print(f"min_hsv_mean_h: {np.min(hsv_mean_h)}")
print(f"max_hsv_mean_h: {np.max(hsv_mean_h)}")
print(f"min_hsv_mean_s: {np.min(hsv_mean_s)}")
print(f"max_hsv_mean_s: {np.max(hsv_mean_s)}")
print(f"min_hsv_mean_v: {np.min(hsv_mean_v)}")
print(f"max_hsv_mean_v: {np.max(hsv_mean_v)}")

print(f"min_hsv_mode_h: {np.min(hsv_mode_h)}")
print(f"max_hsv_mode_h: {np.max(hsv_mode_h)}")
print(f"min_hsv_mode_s: {np.min(hsv_mode_s)}")
print(f"max_hsv_mode_s: {np.max(hsv_mode_s)}")
print(f"min_hsv_mode_v: {np.min(hsv_mode_v)}")
print(f"max_hsv_mode_v: {np.max(hsv_mode_v)}")
# Out:
# min_hsv_mean_h: 76.72900841580558
# max_hsv_mean_h: 141.76643424272388
# min_hsv_mean_s: 15.00552301998128
# max_hsv_mean_s: 204.1701388593755
# min_hsv_mean_v: 65.66314772472921
# max_hsv_mean_v: 250.2541240847304
# min_hsv_mode_h: 0
# max_hsv_mode_h: 143
# min_hsv_mode_s: 0
# max_hsv_mode_s: 255
# min_hsv_mode_v: 6
# max_hsv_mode_v: 255

# %%
# Save to CSV
file = pd.DataFrame(gan_images_path_portions[0])
#                                      TODO: ^~~~~~ ganti index sesuai portion
hsv_mean = pd.DataFrame([hsv_mean_h, hsv_mean_s, hsv_mean_v]).T
merged = pd.concat([file, hsv_mean[0], hsv_mean[1], hsv_mean[2]], axis=1)

# %%
merged.to_csv('datasets/gan/data/portions/1_new.csv', index=False, header=['file', 'hsv_mean_h', 'hsv_mean_s', 'hsv_mean_v'])
#                                   TODO: ^~~~~~ ganti nama file sesuai portion

# %% [markdown]
# ### Note: tunggu setiap cell nya selesai running baru lanjut ke cell selanjutnya

# %% [markdown]
# ## Classify the phototype

# %%
# threshold
